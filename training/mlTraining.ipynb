# %%
import pandas as pd
import numpy as np
import pickle
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

kd = pd.read_csv('data_missing.csv')
kd = kd.dropna()
kd
# Out:
#         Age  Gender  Education  Introversion Score  Sensing Score  \
# 4      31.0  Female        0.0             3.59804       6.189259
# 5      33.0  Female        0.0             1.06869       7.143507
# 7      27.0    Male        1.0             3.98957       4.406797
# 10     32.0    Male        0.0             3.98624       6.287163
# 16     32.0  Female        0.0             5.61706       6.190431
# ...     ...     ...        ...                 ...            ...
# 43722  24.0  Female        0.0             4.30484       6.673149
# 43725  28.0    Male        0.0             7.21415       2.405862
# 43730  21.0  Female        0.0             1.80978       5.889667
# 43739  26.0    Male        1.0             8.88656       5.118399
# 43741  25.0  Female        0.0             2.00982       6.544036
#
#        Thinking Score  Judging Score    Interest Personality
# 4             5.31347       3.677984      Others        ISFP
# 5             3.84411       6.347241      Sports        ISFJ
# 7             5.09055       5.556500  Technology        INFP
# 10            1.83208       5.447141        Arts        ISFP
# 16            0.77300       7.598795      Others        ESFJ
# ...               ...            ...         ...         ...
# 43722         4.31227       6.573628  Technology        ESFJ
# 43725         5.60943       8.164824        Arts        ENTJ
# 43730         9.35024       6.066070      Others        INTJ
# 43739         8.48784       5.331942        Arts        ENTP
# 43741         6.63911       6.201555  Technology        ISTJ
#
# [7271 rows x 9 columns]

# %%
def map_data(x):
    convert = x.unique()
    return x.map(dict(zip(convert, range(1,len(convert) + 1))))
for column in kd.columns:
    if kd[column].dtype == 'object':
        kd[column] = map_data(kd[column])
kd = kd.astype(int)

# %%
scaler = MinMaxScaler()
kd_scaled = pd.DataFrame(scaler.fit_transform(kd), columns=kd.columns)

# %%
rfcX = kd.drop(columns=['Personality'])
rfcy = kd['Personality']
rfcX_train, rfcX_test, rfcy_train, rfcy_test = train_test_split(rfcX, rfcy, test_size=0.3, random_state=42)

# สร้างโมเดล
rfc_model = RandomForestClassifier(n_estimators=150, random_state=42, class_weight="balanced")
rfc_model.fit(rfcX_train, rfcy_train)

# ทดสอบโมเดล
# ทำนายค่า
rfcy_pred = rfc_model.predict(rfcX_test)

# คำนวณค่า Metrics
rfc_acc = accuracy_score(rfcy_test, rfcy_pred)

# แสดงผล
print(f"Random Forest Classifier Accuracy: {rfc_acc:.2f}\n")

#save
pickle.dump(rfc_model, open('rfc_model.pkl', 'wb'))
pickle.dump(scaler, open('rfc_scaler.pkl', 'wb'))
# Out:
# Random Forest Classifier Accuracy: 0.82

# %%
svmX = kd.drop(columns=['Personality'])
svmy = kd['Personality']
svmX_train, svmX_test, svmy_train, svmy_test = train_test_split(svmX, svmy, test_size=0.3, random_state=42)

# สร้างโมเดล
svm_model = SVC(kernel="linear", random_state=42, class_weight="balanced")
svm_model.fit(svmX_train, svmy_train)

# ทดสอบโมเดล
# ทำนายค่า
svmy_pred = svm_model.predict(svmX_test)

# คำนวณค่า Metrics
svm_acc = accuracy_score(svmy_test, svmy_pred)

# แสดงผล
print(f"SVM Accuracy: {svm_acc:.2f}\n")

#save
pickle.dump(rfc_model, open('svm_model.pkl', 'wb'))
pickle.dump(scaler, open('svm_scaler.pkl', 'wb'))
# Out:
# SVM Accuracy: 0.80
